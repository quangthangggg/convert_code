# %%
# %%time
# Import required Azure Packages
from azureml.core import Workspace, Dataset, Datastore, Environment, Experiment
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.core.runconfig import RunConfiguration, DockerConfiguration
from azureml.core.conda_dependencies import CondaDependencies
from azureml.pipeline.core import Pipeline, PipelineData, PipelineParameter, TrainingOutput
from azureml.pipeline.steps import PythonScriptStep, AutoMLStep
from azureml.data import OutputFileDatasetConfig
from azureml.train.automl import AutoMLConfig
from azureml.pipeline.core.graph import PipelineParameter
from azureml.pipeline.core.schedule import ScheduleRecurrence, Schedule

from azureml.pipeline.core import PipelineRun
from azureml.train.automl.run import AutoMLRun
# Out:
# CPU times: user 169 ms, sys: 39.6 ms, total: 208 ms
# Wall time: 329 ms

# %%
import json
import pandas as pd

# %%
# User name - specify your user name (this name will be used for creating base directories,  dataAsset naming)
# Make sure to keep this unique & short
user_name = 'ab'

# Provide model_name to register, it will auto-increment the model version.
# Provide experiment_name and datastore_name for which the specific model iteration needs to be specified.
model_name = f'{user_name}_ChurnPrediction_Model'
experiment_name = f'{user_name}_model_training_pipeline_test'
datastore_name = "bidv_blob_datastore"

# Specify a pipeline_run_id and model_iteration_id to register that specific model to Azure
pipeline_run_id = 'cd4ed604-ae7a-4381-a12d-e9cb7e961aba'
user_selected_iteration_id = '819ad93c-20d6-4328-8d9c-bfe327094ed7_39'

# Specify the columns on which the model was trained, if not specified, NDP will fail
tbl_train_columns = 'AMOUNT_TRANSACTION_AUTO;NO_CREDIT_l6m_min;NO_FEE_TRANSACTION_l1m_mean;AMOUNT_TRANSACTION_AUTO_l6m_min;PRE_CLS_BAL_l3m_std;NO_CREDIT_l2m_min;EMAIL_FLAG;PROVINCE_REGION_CENTRAL;OCCUPATION_GROUP_Manual_Labor_and_Trades;NO_FEE_TRANSACTION_l5m_sum;AMOUNT_TRANSACTION;L3M_LOAN_FLAG;NO_DEPOSIT_l3m_std;PRE_CLS_BAL_l3m_max;AGE_GROUP_genX;OCCUPATION_GROUP_Service_and_Hospitality;NO_TRANSATION_l2m_std;PRE_CLS_BAL_l4m_std;AMOUNT_TRANSACTION_AUTO_l4m_std;NO_FUND_TRANSFER_l6m_min;NO_CREDIT;NO_FEE_TRANSACTION_l2m_std;L3M_FD_FLAG;NO_SMB_l2m_min;NO_DEBIT_l3m_min;NO_TRANSATION_AUTO_l2m_std;NO_DEPOSIT_l3m_sum;AMT_CREDIT;OCCUPATION_GROUP_Other;AGE_GROUP_millennials;NO_FEE_TRANSACTION_l2m_max;NO_TRANSATION_AUTO_l6m_min;GENDER_Female;num_of_PRODUCT_ID;NO_FEE_TRANSACTION_l4m_std;No_of_Accounts_l5m_max;NO_ATM_l3m_std;NO_DEPOSIT_l2m_std;NO_DEBIT_l6m_max;NO_SMB_l2m_max;NO_WITHDRAW_l2m_std;AMT_CREDIT_l6m_std;AMT_DEBIT;MARITAL_GROUP_SINGLE;NO_ATM_l6m_mean;AMT_CREDIT_l6m_min;NO_FEE_TRANSACTION_l3m_std;NO_DEBIT_l2m_std;NO_CREDIT_l2m_max;AGE_GROUP_boomers;NO_CREDIT_l3m_min;PRE_CLS_BAL_l2m_std;AMOUNT_TRANSACTION_AUTO_l4m_min;L6M_LOAN_FLAG;NO_FUND_TRANSFER_l3m_min;MARITAL_GROUP_OTHER;NO_ATM_l2m_max;NO_SMB_l6m_max;NO_TRANSATION_AUTO_l5m_std;churn_flag;NO_CREDIT_l5m_std;NO_TRANSATION_AUTO_l5m_min;NO_FEE_TRANSACTION_l3m_min;NO_DEBIT_l6m_min;AMT_CREDIT_l2m_min;NO_TRANSATION_AUTO_l3m_std;PRE_CLS_BAL_l2m_max;L6M_FD_FLAG;AMOUNT_TRANSACTION_AUTO_l5m_sum;AMOUNT_TRANSACTION_AUTO_l6m_std;NO_DEBIT_l2m_max;NO_FEE_TRANSACTION_l3m_mean;AMT_CREDIT_l5m_min;NO_FEE_TRANSACTION_l6m_std;NO_ATM_l6m_min;AMOUNT_TRANSACTION_AUTO_l5m_std;NO_ATM_l4m_std;PRE_CLS_BAL_l6m_sum;NO_FEE_TRANSACTION_l3m_max;NO_CREDIT_l2m_std;OCCUPATION_GROUP_Business_and_Sales;NO_SMB_l2m_std;PRE_CLS_BAL_l5m_std;PROVINCE_REGION_SOUTH;NO_ATM_l1m_mean;num_of_Closed;AGE_GROUP_genZ;PRE_CLS_BAL_l6m_min;NO_FUND_TRANSFER_l5m_min;AMT_DEBIT_l3m_min;NO_DEBIT_l5m_min;PRE_CLS_BAL_l5m_min;AMT_CREDIT_l3m_std;NO_TRANSATION_AUTO;NO_DEPOSIT_l6m_std;NO_DEBIT;PROVINCE_REGION_NORTH;PRE_CLS_BAL;NO_CREDIT_l5m_min;NO_CREDIT_l1m_mean;GENDER_Male;NO_ATM_l2m_min;NO_DEPOSIT_l6m_sum;NO_ATM_l6m_std;AMT_DEBIT_l1m_mean;AMOUNT_TRANSACTION_AUTO_l2m_min;MARITAL_GROUP_MARRIED;PRE_CLS_BAL_l4m_min;NO_ATM_l3m_min'

# Specify user_selected_metric
user_selected_metric = 'f1_score_macro'

# Specify other variables
observation_month_number = 7
observation_year = 2022
historical_months = 6

# %%
model_tags = {}
model_tags['pipeline_run_id'] = pipeline_run_id
model_tags['custom_model_iteration_selected'] = user_selected_iteration_id
model_tags['observation_year'] = observation_year
model_tags['observation_month_number'] = observation_month_number
model_tags['model_name'] = model_name
model_tags['historical_months'] = historical_months

# %%
# Loads workspace info from config.json file and get workspace details
ws = Workspace.from_config(path='../Configurations/', _file_name='workspace_config.json')
ws_details = ws.get_details()['id']

# Load the automl step run id as specified from the workspace
automl_step_run_id, user_selected_model_iteration_num = user_selected_iteration_id.split('_')

# Get current experiment
experiment = Experiment(ws, experiment_name)
print('Experiment Name:', experiment_name)

# Get the pipeline
pipeline_run = PipelineRun(experiment, pipeline_run_id)
print('Details of current_pipeline_run:', pipeline_run)

# Get model trainig step run
automl_step_run = pipeline_run.find_step_run('Model_Training_Testing')[0]
print('Details of automl_step_run:', automl_step_run)
# Convert normal run to AutoMLRun object
automl_step_run = AutoMLRun(experiment, automl_step_run.id)
# Out:
# Experiment Name: ab_model_training_pipeline_test
# Details of current_pipeline_run: Run(Experiment: ab_model_training_pipeline_test,
# Id: cd4ed604-ae7a-4381-a12d-e9cb7e961aba,
# Type: azureml.PipelineRun,
# Status: Completed)
# Details of automl_step_run: Run(Experiment: ab_model_training_pipeline_test,
# Id: 819ad93c-20d6-4328-8d9c-bfe327094ed7,
# Type: azureml.StepRun,
# Status: Completed)

# %%
def fun_get_model_metrics(current_pipeline_run, best_run):
    metrics_output_port = current_pipeline_run.get_pipeline_output('metrics_output')
    metrics_output_port.download('.', show_progress=True)

    # model_output_port = current_pipeline_run.get_pipeline_output('model_output')
    # model_output_port.download('.', show_progress=True)

    metrics_filename = metrics_output_port._path_on_datastore
    # metrics_filename = path to downloaded file
    with open(metrics_filename) as f:
        metrics_output_result = f.read()
    
    deserialized_metrics_output = json.loads(metrics_output_result)
    df = pd.DataFrame(deserialized_metrics_output)
    print(df.to_dict)

    df_best_run = df[[best_run.id]]
    dict_metrics = {}
    df_best_run['metrics'] = [i[0] for i in df_best_run[best_run.id]]
    df_best_run.drop(columns=best_run.id, inplace=True)
    dict_metrics = df_best_run.to_dict()
    
    return dict_metrics

# %%
model_properties = {
    'train_columns' : tbl_train_columns
}

# %%
# Register best model from this run based on user_selected_iteration_number
best_run, model = automl_step_run.get_output(iteration=user_selected_model_iteration_num)
model_path_on_datastore = best_run.properties['model_data_location'].split('artifact/')[1].split('/model.pkl')[0]
model_path = f'azureml:/{ws_details}/datastores/{datastore_name}/paths/{model_path_on_datastore}'
dict_metrics = fun_get_model_metrics(pipeline_run, best_run)
model_properties['best_model_as_per_user_selected_iteration_number'] = dict_metrics
model_properties['best_model_as_per_user_selected_iteration_number']['run_id'] = best_run.id
model_properties['best_model_as_per_user_selected_iteration_number']['model_path'] = model_path
print(f'Model path for Model selected based on user_selected_iteration_number {user_selected_model_iteration_num}:', model_path)

model = best_run.register_model(
    model_name=model_name+'_test',
    model_path='outputs/model.pkl',
    properties=model_properties,
    tags=model_tags,
)

print("Trained_Model_Name", model.name)
print("Trained_Model_Version", model.version)
print("Trained_Model_Columns", tbl_train_columns)
print("user_selected_metric", user_selected_metric)

print("Registered version {0} of model {1}".format(model.version, model.name))
# Out:
# WARNING:azureml.data.azure_storage_datastore:Path already exists. Skipping download for ./azureml/819ad93c-20d6-4328-8d9c-bfe327094ed7/metrics_data
# <bound method DataFrame.to_dict of                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_2  \
# balanced_accuracy                                  [0.6403497687463984]
# f1_score_micro                                     [0.8418604651162791]
# recall_score_macro                                 [0.6403497687463984]
# log_loss                                          [0.31025587064795296]
# f1_score_weighted                                  [0.8222803588217082]
# recall_score_weighted                              [0.8418604651162791]
# AUC_micro                                          [0.9402514872904272]
# matthews_correlation                              [0.34859384025627194]
# average_precision_score_macro                      [0.7963494439960137]
# average_precision_score_weighted                   [0.9083282228675442]
# AUC_weighted                                       [0.8763048613712524]
# precision_score_macro                              [0.7243699695366361]
# accuracy                                           [0.8418604651162791]
# recall_score_micro                                 [0.8418604651162791]
# average_precision_score_micro                      [0.9392631314029096]
# precision_score_micro                              [0.8418604651162791]
# precision_score_weighted                           [0.8234242256451558]
# AUC_macro                                          [0.8763048613712524]
# norm_macro_recall                                  [0.2806995374927967]
# weighted_accuracy                                  [0.9209058840451668]
# f1_score_macro                                     [0.6565259048171186]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_1  \
# balanced_accuracy                                  [0.6692869581515659]
# f1_score_micro                                     [0.8581395348837209]
# recall_score_macro                                 [0.6692869581515659]
# log_loss                                          [0.45714288786959295]
# f1_score_weighted                                  [0.8421149467301412]
# recall_score_weighted                              [0.8581395348837209]
# AUC_micro                                          [0.9370200108166575]
# matthews_correlation                               [0.4226212977784023]
# average_precision_score_macro                      [0.7844451496487691]
# average_precision_score_weighted                   [0.9052778887117823]
# AUC_weighted                                        [0.868585244989705]
# precision_score_macro                              [0.7643651706942846]
# accuracy                                           [0.8581395348837209]
# recall_score_micro                                 [0.8581395348837209]
# average_precision_score_micro                      [0.9392527431575216]
# precision_score_micro                              [0.8581395348837209]
# precision_score_weighted                           [0.8417386362043413]
# AUC_macro                                           [0.868585244989705]
# norm_macro_recall                                  [0.3385739163031319]
# weighted_accuracy                                  [0.9330993163106995]
# f1_score_macro                                     [0.6979050238605019]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_20  \
# balanced_accuracy                                   [0.8211630321101119]
# f1_score_micro                                      [0.8162790697674419]
# recall_score_macro                                  [0.8211630321101119]
# log_loss                                            [0.3854843923427069]
# f1_score_weighted                                   [0.8332577610861153]
# recall_score_weighted                               [0.8162790697674419]
# AUC_micro                                           [0.9054894537587886]
# matthews_correlation                                [0.5314918640428771]
# average_precision_score_macro                        [0.783580738313119]
# average_precision_score_weighted                     [0.903912471595822]
# AUC_weighted                                        [0.8652951069861521]
# precision_score_macro                               [0.7206058011482669]
# accuracy                                            [0.8162790697674419]
# recall_score_micro                                  [0.8162790697674419]
# average_precision_score_micro                       [0.9093998406772249]
# precision_score_micro                               [0.8162790697674419]
# precision_score_weighted                            [0.8770461539541922]
# AUC_macro                                           [0.8652951069861521]
# norm_macro_recall                                   [0.6423260642202239]
# weighted_accuracy                                   [0.8149300958615864]
# f1_score_macro                                      [0.7432283566588385]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_25  \
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.8279069767441861]
# recall_score_macro                                                 [0.5]
# log_loss                                           [0.45495472610802495]
# f1_score_weighted                                   [0.7501108427333726]
# recall_score_weighted                               [0.8279069767441861]
# AUC_micro                                           [0.8980530016224986]
# matthews_correlation                                               [0.0]
# average_precision_score_macro                       [0.6734273837451553]
# average_precision_score_weighted                    [0.8411250512415617]
# AUC_weighted                                        [0.7478322159180864]
# precision_score_macro                              [0.41395348837209306]
# accuracy                                            [0.8279069767441861]
# recall_score_micro                                  [0.8279069767441861]
# average_precision_score_micro                       [0.8932878948891396]
# precision_score_micro                               [0.8279069767441861]
# precision_score_weighted                            [0.6858842617631151]
# AUC_macro                                           [0.7478322159180864]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9575272853996972]
# f1_score_macro                                      [0.4528515553774997]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_0  \
# balanced_accuracy                                  [0.6544780635792442]
# f1_score_micro                                      [0.855813953488372]
# recall_score_macro                                 [0.6544780635792442]
# log_loss                                           [0.4687515573853115]
# f1_score_weighted                                  [0.8354025152032554]
# recall_score_weighted                               [0.855813953488372]
# AUC_micro                                           [0.942671714440238]
# matthews_correlation                               [0.4030759951323585]
# average_precision_score_macro                      [0.8069252163703929]
# average_precision_score_weighted                   [0.9167618292994263]
# AUC_weighted                                       [0.8847074698299167]
# precision_score_macro                              [0.7646089599570614]
# accuracy                                            [0.855813953488372]
# recall_score_micro                                  [0.855813953488372]
# average_precision_score_micro                      [0.9457145027273615]
# precision_score_micro                               [0.855813953488372]
# precision_score_weighted                           [0.8374203052205702]
# AUC_macro                                          [0.8847074698299167]
# norm_macro_recall                                  [0.3089561271584885]
# weighted_accuracy                                  [0.9364887675234789]
# f1_score_macro                                      [0.682588409098531]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_18  \
# balanced_accuracy                                    [0.605323834608598]
# f1_score_micro                                      [0.8302325581395349]
# recall_score_macro                                   [0.605323834608598]
# log_loss                                            [0.6345379743208944]
# f1_score_weighted                                   [0.8050789094717545]
# recall_score_weighted                               [0.8302325581395349]
# AUC_micro                                           [0.9222687939426717]
# matthews_correlation                                [0.2778705279238422]
# average_precision_score_macro                       [0.7250338761386542]
# average_precision_score_weighted                    [0.8722137524371897]
# AUC_weighted                                        [0.8331341645407265]
# precision_score_macro                               [0.6873215706042602]
# accuracy                                            [0.8302325581395349]
# recall_score_micro                                  [0.8302325581395349]
# average_precision_score_micro                       [0.9159678861643294]
# precision_score_micro                               [0.8302325581395349]
# precision_score_weighted                            [0.8016650756262615]
# AUC_macro                                           [0.8331341645407265]
# norm_macro_recall                                   [0.2106476692171959]
# weighted_accuracy                                   [0.9198289367545589]
# f1_score_macro                                      [0.6203286050303549]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_38  \
# balanced_accuracy                                   [0.8324205597389917]
# f1_score_micro                                      [0.8348837209302327]
# recall_score_macro                                  [0.8324205597389917]
# log_loss                                              [0.37904880806256]
# f1_score_weighted                                   [0.8484172194346842]
# recall_score_weighted                               [0.8348837209302327]
# AUC_micro                                           [0.9088967009194159]
# matthews_correlation                                 [0.559885276464962]
# average_precision_score_macro                        [0.788383310865901]
# average_precision_score_weighted                    [0.9064063489243411]
# AUC_weighted                                        [0.8724508000845457]
# precision_score_macro                               [0.7367280458134963]
# accuracy                                            [0.8348837209302327]
# recall_score_micro                                  [0.8348837209302327]
# average_precision_score_micro                       [0.9125503397994248]
# precision_score_micro                               [0.8348837209302327]
# precision_score_weighted                             [0.883847701270865]
# AUC_macro                                           [0.8724508000845457]
# norm_macro_recall                                   [0.6648411194779833]
# weighted_accuracy                                   [0.8364617644799608]
# f1_score_macro                                      [0.7613037633839527]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_29  \
# balanced_accuracy                                   [0.6620537680718812]
# f1_score_micro                                      [0.8534883720930232]
# recall_score_macro                                  [0.6620537680718812]
# log_loss                                            [0.4767799249131106]
# f1_score_weighted                                   [0.8364691038287516]
# recall_score_weighted                               [0.8534883720930232]
# AUC_micro                                           [0.9388047593293672]
# matthews_correlation                               [0.40651642532312626]
# average_precision_score_macro                       [0.7980721062735185]
# average_precision_score_weighted                    [0.9096381050097524]
# AUC_weighted                                        [0.8710666488155715]
# precision_score_macro                               [0.7582300631542804]
# accuracy                                            [0.8534883720930232]
# recall_score_micro                                  [0.8534883720930232]
# average_precision_score_micro                        [0.939956475387303]
# precision_score_micro                               [0.8534883720930232]
# precision_score_weighted                            [0.8380117531227063]
# AUC_macro                                           [0.8710666488155715]
# norm_macro_recall                                  [0.32410753614376225]
# weighted_accuracy                                   [0.9297916067197303]
# f1_score_macro                                      [0.6873598282710516]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_28  \
# balanced_accuracy                                   [0.6652335858367108]
# f1_score_micro                                      [0.8558139534883722]
# recall_score_macro                                  [0.6652335858367108]
# log_loss                                           [0.32672118940848094]
# f1_score_weighted                                   [0.8386527286738659]
# recall_score_weighted                               [0.8558139534883722]
# AUC_micro                                           [0.9414818820984318]
# matthews_correlation                                [0.4149666020639019]
# average_precision_score_macro                        [0.798062955871257]
# average_precision_score_weighted                     [0.912879984295911]
# AUC_weighted                                        [0.8828845176377846]
# precision_score_macro                               [0.7620074224021594]
# accuracy                                            [0.8558139534883722]
# recall_score_micro                                  [0.8558139534883722]
# average_precision_score_micro                       [0.9445228461838988]
# precision_score_micro                               [0.8558139534883722]
# precision_score_weighted                            [0.8391831434579293]
# AUC_macro                                           [0.8828845176377845]
# norm_macro_recall                                   [0.3304671716734219]
# weighted_accuracy                                   [0.9322467497240272]
# f1_score_macro                                      [0.6925962667285166]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_36  ...  \
# balanced_accuracy                                   [0.7779384729258604]  ...
# f1_score_micro                                      [0.8116279069767443]  ...
# recall_score_macro                                  [0.7779384729258604]  ...
# log_loss                                            [0.4874289862366011]  ...
# f1_score_weighted                                   [0.8254200755949384]  ...
# recall_score_weighted                               [0.8116279069767443]  ...
# AUC_micro                                           [0.8920767982693347]  ...
# matthews_correlation                               [0.47682158478545905]  ...
# average_precision_score_macro                       [0.7527078663842086]  ...
# average_precision_score_weighted                    [0.8814136857303894]  ...
# AUC_weighted                                        [0.8375332839187812]  ...
# precision_score_macro                               [0.7064301978051313]  ...
# accuracy                                            [0.8116279069767443]  ...
# recall_score_micro                                  [0.8116279069767443]  ...
# average_precision_score_micro                       [0.8875824780129978]  ...
# precision_score_micro                               [0.8116279069767443]  ...
# precision_score_weighted                            [0.8581906180747584]  ...
# AUC_macro                                           [0.8375332839187812]  ...
# norm_macro_recall                                   [0.5558769458517208]  ...
# weighted_accuracy                                   [0.8265146230937643]  ...
# f1_score_macro                                      [0.7221095741083858]  ...
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_23  \
# balanced_accuracy                                    [0.644075976322937]
# f1_score_micro                                      [0.8511627906976745]
# recall_score_macro                                   [0.644075976322937]
# log_loss                                           [0.32288459825009175]
# f1_score_weighted                                   [0.8299928484813673]
# recall_score_weighted                               [0.8511627906976745]
# AUC_micro                                           [0.9371011357490536]
# matthews_correlation                                [0.3784969273604424]
# average_precision_score_macro                       [0.7912669371304324]
# average_precision_score_weighted                    [0.9048263242467103]
# AUC_weighted                                        [0.8697344306302721]
# precision_score_macro                               [0.7515480743584229]
# accuracy                                            [0.8511627906976745]
# recall_score_micro                                  [0.8511627906976745]
# average_precision_score_micro                       [0.9365350611170544]
# precision_score_micro                               [0.8511627906976745]
# precision_score_weighted                            [0.8313894983153979]
# AUC_macro                                           [0.8697344306302721]
# norm_macro_recall                                   [0.2881519526458741]
# weighted_accuracy                                   [0.9334360162501447]
# f1_score_macro                                      [0.6697540952366386]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_19  \
# balanced_accuracy                                   [0.7990987437414757]
# f1_score_micro                                      [0.7906976744186046]
# recall_score_macro                                  [0.7990987437414757]
# log_loss                                            [0.4803751827054092]
# f1_score_weighted                                   [0.8113349357540018]
# recall_score_weighted                               [0.7906976744186046]
# AUC_micro                                           [0.8868848025959979]
# matthews_correlation                                [0.4839510505609567]
# average_precision_score_macro                       [0.7738932299852556]
# average_precision_score_weighted                     [0.899786298818946]
# AUC_weighted                                        [0.8617722007863637]
# precision_score_macro                               [0.6959469429102189]
# accuracy                                            [0.7906976744186046]
# recall_score_micro                                  [0.7906976744186046]
# average_precision_score_micro                       [0.8922343464317957]
# precision_score_micro                               [0.7906976744186046]
# precision_score_weighted                             [0.864849677250908]
# AUC_macro                                           [0.8617722007863637]
# norm_macro_recall                                   [0.5981974874829514]
# weighted_accuracy                                   [0.7872426506355855]
# f1_score_macro                                      [0.7151457123385953]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_22  \
# balanced_accuracy                                   [0.6322744560324702]
# f1_score_micro                                      [0.8116279069767443]
# recall_score_macro                                  [0.6322744560324702]
# log_loss                                            [0.3985358815295702]
# f1_score_weighted                                   [0.8018516650660403]
# recall_score_weighted                               [0.8116279069767443]
# AUC_micro                                           [0.9111681990265008]
# matthews_correlation                               [0.27891704459909966]
# average_precision_score_macro                       [0.7059379320460165]
# average_precision_score_weighted                    [0.8655140554940136]
# AUC_weighted                                        [0.8104696876383455]
# precision_score_macro                               [0.6485475667054614]
# accuracy                                            [0.8116279069767443]
# recall_score_micro                                  [0.8116279069767443]
# average_precision_score_micro                        [0.908561572192157]
# precision_score_micro                               [0.8116279069767443]
# precision_score_weighted                            [0.7967338257362737]
# AUC_macro                                           [0.8104696876383454]
# norm_macro_recall                                  [0.26454891206494047]
# weighted_accuracy                                    [0.881719682687273]
# f1_score_macro                                      [0.6354379666152676]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_16  \
# balanced_accuracy                                   [0.6492037242654731]
# f1_score_micro                                      [0.8255813953488372]
# recall_score_macro                                  [0.6492037242654731]
# log_loss                                             [0.932315143557051]
# f1_score_weighted                                   [0.8168914194113152]
# recall_score_weighted                               [0.8255813953488372]
# AUC_micro                                           [0.9143320713899404]
# matthews_correlation                               [0.33583599152813837]
# average_precision_score_macro                       [0.7016264327333271]
# average_precision_score_weighted                    [0.8633072106280995]
# AUC_weighted                                        [0.8183940876407068]
# precision_score_macro                               [0.6897030914226301]
# accuracy                                            [0.8255813953488372]
# recall_score_micro                                  [0.8255813953488372]
# average_precision_score_micro                        [0.909347832032908]
# precision_score_micro                               [0.8255813953488372]
# precision_score_weighted                            [0.8136943553100224]
# AUC_macro                                           [0.8183940876407068]
# norm_macro_recall                                  [0.29840744853094636]
# weighted_accuracy                                   [0.8956189214911111]
# f1_score_macro                                      [0.6633874467267598]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_27  \
# balanced_accuracy                                   [0.6686348996311159]
# f1_score_micro                                      [0.8627906976744187]
# recall_score_macro                                  [0.6686348996311159]
# log_loss                                            [0.3444583973983399]
# f1_score_weighted                                   [0.8442030092062197]
# recall_score_weighted                               [0.8627906976744187]
# AUC_micro                                           [0.9295294753921037]
# matthews_correlation                               [0.44757272491325806]
# average_precision_score_macro                       [0.7795174927794981]
# average_precision_score_weighted                    [0.8927395522895333]
# AUC_weighted                                         [0.845164408672099]
# precision_score_macro                               [0.8025965490792192]
# accuracy                                            [0.8627906976744187]
# recall_score_micro                                  [0.8627906976744187]
# average_precision_score_micro                       [0.9264557651629651]
# precision_score_micro                               [0.8627906976744187]
# precision_score_weighted                            [0.8505653838719486]
# AUC_macro                                            [0.845164408672099]
# norm_macro_recall                                   [0.3372697992622318]
# weighted_accuracy                                   [0.9401065055246601]
# f1_score_macro                                      [0.7017992519276163]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_35  \
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                     [0.44651162790697674]
# recall_score_macro                                                 [0.5]
# log_loss                                             [0.693750939442966]
# f1_score_weighted                                    [0.342532888582448]
# recall_score_weighted                              [0.44651162790697674]
# AUC_micro                                           [0.4465116279069766]
# matthews_correlation                                               [0.0]
# average_precision_score_macro                                      [0.5]
# average_precision_score_weighted                    [0.7159545700378581]
# AUC_weighted                                                       [0.5]
# precision_score_macro                              [0.22325581395348837]
# accuracy                                           [0.44651162790697674]
# recall_score_micro                                 [0.44651162790697674]
# average_precision_score_micro                       [0.5812330989724176]
# precision_score_micro                              [0.44651162790697674]
# precision_score_weighted                            [0.3044889129259059]
# AUC_macro                                                          [0.5]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                    [0.415604843755751]
# f1_score_macro                                      [0.2752451836157527]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_37  \
# balanced_accuracy                                   [0.7998755107485794]
# f1_score_micro                                      [0.7883720930232558]
# recall_score_macro                                  [0.7998755107485794]
# log_loss                                            [0.4620948066705567]
# f1_score_weighted                                   [0.8097156613512944]
# recall_score_weighted                               [0.7883720930232558]
# AUC_micro                                           [0.8643320713899406]
# matthews_correlation                                [0.4856605955811407]
# average_precision_score_macro                       [0.7410095432851708]
# average_precision_score_weighted                    [0.8824214868140045]
# AUC_weighted                                        [0.8308222183209046]
# precision_score_macro                               [0.6973569626796944]
# accuracy                                            [0.7883720930232558]
# recall_score_micro                                  [0.7883720930232558]
# average_precision_score_micro                       [0.8708522548348567]
# precision_score_micro                               [0.7883720930232558]
# precision_score_weighted                            [0.8660117370694319]
# AUC_macro                                           [0.8308222183209045]
# norm_macro_recall                                   [0.5997510214971589]
# weighted_accuracy                                   [0.7847164889702346]
# f1_score_macro                                      [0.7140927619026703]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_30  \
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.6930232558139535]
# recall_score_macro                                                 [0.5]
# log_loss                                            [0.6904296359792024]
# f1_score_weighted                                   [0.6066218818855658]
# recall_score_weighted                               [0.6930232558139535]
# AUC_micro                                           [0.6930232558139535]
# matthews_correlation                                               [0.0]
# average_precision_score_macro                                      [0.5]
# average_precision_score_weighted                    [0.7159545700378581]
# AUC_weighted                                                       [0.5]
# precision_score_macro                              [0.34651162790697676]
# accuracy                                            [0.6930232558139535]
# recall_score_micro                                  [0.6930232558139535]
# average_precision_score_micro                       [0.7044889129259059]
# precision_score_micro                               [0.6930232558139535]
# precision_score_weighted                            [0.5510005408328826]
# AUC_macro                                                          [0.5]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.7720997761060169]
# f1_score_macro                                      [0.3897123148711706]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_33  \
# balanced_accuracy                                   [0.5950558428499605]
# f1_score_micro                                      [0.8581395348837211]
# recall_score_macro                                  [0.5950558428499605]
# log_loss                                           [0.32356041703493144]
# f1_score_weighted                                   [0.8158715683434747]
# recall_score_weighted                               [0.8581395348837211]
# AUC_micro                                            [0.934586262844781]
# matthews_correlation                                [0.3877784130704898]
# average_precision_score_macro                       [0.8030486247517062]
# average_precision_score_weighted                    [0.9095220176482343]
# AUC_weighted                                        [0.8689952571184396]
# precision_score_macro                               [0.9077862773846709]
# accuracy                                            [0.8581395348837211]
# recall_score_micro                                  [0.8581395348837211]
# average_precision_score_micro                       [0.9342567993841999]
# precision_score_micro                               [0.8581395348837211]
# precision_score_weighted                            [0.8744102878846505]
# AUC_macro                                           [0.8689952571184397]
# norm_macro_recall                                  [0.19011168569992098]
# weighted_accuracy                                   [0.9626633226747563]
# f1_score_macro                                      [0.6177039451984238]
#
#                                  819ad93c-20d6-4328-8d9c-bfe327094ed7_32
# balanced_accuracy                                   [0.7868438230654886]
# f1_score_micro                                      [0.7348837209302326]
# recall_score_macro                                  [0.7868438230654886]
# log_loss                                            [0.4543251373155018]
# f1_score_weighted                                   [0.7657173573637046]
# recall_score_weighted                               [0.7348837209302326]
# AUC_micro                                           [0.8607355327203894]
# matthews_correlation                                [0.4438716028686181]
# average_precision_score_macro                       [0.7393517896000859]
# average_precision_score_weighted                    [0.8883571130607558]
# AUC_weighted                                        [0.8562926842977994]
# precision_score_macro                               [0.6719684165674111]
# accuracy                                            [0.7348837209302326]
# recall_score_micro                                  [0.7348837209302326]
# average_precision_score_micro                       [0.8712332116137566]
# precision_score_micro                               [0.7348837209302326]
# precision_score_weighted                            [0.8627537533303371]
# AUC_macro                                           [0.8562926842977994]
# norm_macro_recall                                   [0.5736876461309772]
# weighted_accuracy                                   [0.7141493828806693]
# f1_score_macro                                      [0.6714500184961091]
#
# [21 rows x 40 columns]>
# Model path for Model selected based on user_selected_iteration_number 39: azureml://subscriptions/bdea9b80-e147-4dd1-9e22-afd1228b6d1a/resourceGroups/casa-churn-analysis-ey-demo/providers/Microsoft.MachineLearningServices/workspaces/AzureConnection/datastores/bidv_blob_datastore/paths/ExperimentRun/dcid.819ad93c-20d6-4328-8d9c-bfe327094ed7_39/outputs
# Trained_Model_Name ab_ChurnPrediction_Model_test
# Trained_Model_Version 6
# Trained_Model_Columns AMOUNT_TRANSACTION_AUTO;NO_CREDIT_l6m_min;NO_FEE_TRANSACTION_l1m_mean;AMOUNT_TRANSACTION_AUTO_l6m_min;PRE_CLS_BAL_l3m_std;NO_CREDIT_l2m_min;EMAIL_FLAG;PROVINCE_REGION_CENTRAL;OCCUPATION_GROUP_Manual_Labor_and_Trades;NO_FEE_TRANSACTION_l5m_sum;AMOUNT_TRANSACTION;L3M_LOAN_FLAG;NO_DEPOSIT_l3m_std;PRE_CLS_BAL_l3m_max;AGE_GROUP_genX;OCCUPATION_GROUP_Service_and_Hospitality;NO_TRANSATION_l2m_std;PRE_CLS_BAL_l4m_std;AMOUNT_TRANSACTION_AUTO_l4m_std;NO_FUND_TRANSFER_l6m_min;NO_CREDIT;NO_FEE_TRANSACTION_l2m_std;L3M_FD_FLAG;NO_SMB_l2m_min;NO_DEBIT_l3m_min;NO_TRANSATION_AUTO_l2m_std;NO_DEPOSIT_l3m_sum;AMT_CREDIT;OCCUPATION_GROUP_Other;AGE_GROUP_millennials;NO_FEE_TRANSACTION_l2m_max;NO_TRANSATION_AUTO_l6m_min;GENDER_Female;num_of_PRODUCT_ID;NO_FEE_TRANSACTION_l4m_std;No_of_Accounts_l5m_max;NO_ATM_l3m_std;NO_DEPOSIT_l2m_std;NO_DEBIT_l6m_max;NO_SMB_l2m_max;NO_WITHDRAW_l2m_std;AMT_CREDIT_l6m_std;AMT_DEBIT;MARITAL_GROUP_SINGLE;NO_ATM_l6m_mean;AMT_CREDIT_l6m_min;NO_FEE_TRANSACTION_l3m_std;NO_DEBIT_l2m_std;NO_CREDIT_l2m_max;AGE_GROUP_boomers;NO_CREDIT_l3m_min;PRE_CLS_BAL_l2m_std;AMOUNT_TRANSACTION_AUTO_l4m_min;L6M_LOAN_FLAG;NO_FUND_TRANSFER_l3m_min;MARITAL_GROUP_OTHER;NO_ATM_l2m_max;NO_SMB_l6m_max;NO_TRANSATION_AUTO_l5m_std;churn_flag;NO_CREDIT_l5m_std;NO_TRANSATION_AUTO_l5m_min;NO_FEE_TRANSACTION_l3m_min;NO_DEBIT_l6m_min;AMT_CREDIT_l2m_min;NO_TRANSATION_AUTO_l3m_std;PRE_CLS_BAL_l2m_max;L6M_FD_FLAG;AMOUNT_TRANSACTION_AUTO_l5m_sum;AMOUNT_TRANSACTION_AUTO_l6m_std;NO_DEBIT_l2m_max;NO_FEE_TRANSACTION_l3m_mean;AMT_CREDIT_l5m_min;NO_FEE_TRANSACTION_l6m_std;NO_ATM_l6m_min;AMOUNT_TRANSACTION_AUTO_l5m_std;NO_ATM_l4m_std;PRE_CLS_BAL_l6m_sum;NO_FEE_TRANSACTION_l3m_max;NO_CREDIT_l2m_std;OCCUPATION_GROUP_Business_and_Sales;NO_SMB_l2m_std;PRE_CLS_BAL_l5m_std;PROVINCE_REGION_SOUTH;NO_ATM_l1m_mean;num_of_Closed;AGE_GROUP_genZ;PRE_CLS_BAL_l6m_min;NO_FUND_TRANSFER_l5m_min;AMT_DEBIT_l3m_min;NO_DEBIT_l5m_min;PRE_CLS_BAL_l5m_min;AMT_CREDIT_l3m_std;NO_TRANSATION_AUTO;NO_DEPOSIT_l6m_std;NO_DEBIT;PROVINCE_REGION_NORTH;PRE_CLS_BAL;NO_CREDIT_l5m_min;NO_CREDIT_l1m_mean;GENDER_Male;NO_ATM_l2m_min;NO_DEPOSIT_l6m_sum;NO_ATM_l6m_std;AMT_DEBIT_l1m_mean;AMOUNT_TRANSACTION_AUTO_l2m_min;MARITAL_GROUP_MARRIED;PRE_CLS_BAL_l4m_min;NO_ATM_l3m_min
# user_selected_metric f1_score_macro
# Registered version 6 of model ab_ChurnPrediction_Model_test
